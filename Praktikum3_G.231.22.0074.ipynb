# %% [markdown]
# **NAMA : Rio Dwi Saputra**
#
# **NIM : G.231.22.0074**

# %%
def convert(s):
 new = ""
 for x in s:
    new += x
 return new

# driver code
s = ['g', 'e', 'e', 'k', 's', 'f', 'o', 'r',
'g', 'e', 'e', 'k', 's']
print(convert(s))
# Out:
# geeksforgeeks

# %%
hasil = ""
for char in s:
    hasil += char

# driver code
s = ['p', 'r', 'o', 'g', 'r', 'a', 'm', 'm', 'i', 'n', 'g']
print(hasil)
# Out:
# programming
